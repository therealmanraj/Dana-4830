# %%
import boto3
import sagemaker
from sagemaker.sklearn.estimator import SKLearn

# Create a boto3 session in us-east-2
boto_session = boto3.Session(region_name="us-east-2")
sagemaker_session = sagemaker.Session(boto_session=boto_session)

role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
job_name = "occupancy-model-t1"

sklearn_estimator = SKLearn(
    entry_point="hvac_test.py",      # Your training script
    source_dir=".",                        # Packages all the files from the current directory
    dependencies=["requirements.txt"],     # Installs any extra packages listed here
    role=role,
    instance_type="ml.m5.xlarge",
    framework_version="0.23-1",
    output_path="s3://dana-minicapstone/model-artifacts/",  # Where the model artifacts will be stored
    sagemaker_session=sagemaker_session,
    job_name=job_name
)

sklearn_estimator.fit()  # Submits the training job to SageMaker
# Out:
# [04/09/25 00:26:12] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=536169;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=908832;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/credentials.py#1352\1352]8;;\
#                     INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=626937;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=673382;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py#91\91]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
# [04/09/25 00:26:13] INFO     Creating training-job with name:                                       ]8;id=682122;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=610551;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              sagemaker-scikit-learn-2025-04-09-07-26-12-644
# 2025-04-09 07:26:17 Starting - Starting the training job...
# 2025-04-09 07:26:48 Downloading - Downloading input data...
# 2025-04-09 07:27:03 Downloading - Downloading the training image...
# 2025-04-09 07:27:38 Training - Training image download completed. Training in progress....
# 2025-04-09 07:28:17 Uploading - Uploading generated training model
# 2025-04-09 07:28:17 Completed - Training job completed
# ..Training seconds: 90
# Billable seconds: 90

# %%
# import boto3
# import io

# # 1. Retrieve the test CSV from S3
# s3 = boto3.client('s3', region_name='us-east-2')
# bucket_name = "dana-minicapstone"
# key = "data/hvac_test.csv"

# response = s3.get_object(Bucket=bucket_name, Key=key)
# csv_bytes = response['Body'].read()       # Get the raw bytes
# csv_str = csv_bytes.decode('utf-8')       # Convert bytes to string


# predictor = sklearn_estimator.deploy(
#     initial_instance_count=1,
#     instance_type="ml.m5.large"
# )

# # 2. Invoke the deployed endpoint with the CSV string
# result = predictor.predict(csv_str)

# # 3. Examine the result (e.g. printing)
# print(result)
# Out:
# [04/09/25 00:34:57] INFO     Created S3 bucket: sagemaker-us-east-2-222634404112                     ]8;id=656670;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=132066;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#723\723]8;;\
#                     INFO     Creating model with name:                                              ]8;id=374114;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=833831;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#4094\4094]8;;\
#                              sagemaker-scikit-learn-2025-04-09-07-34-55-543
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:14                                                                                   │
# │                                                                                                  │
# │   11 csv_str = csv_bytes.decode('utf-8')       # Convert bytes to string                         │
# │   12                                                                                             │
# │   13                                                                                             │
# │ ❱ 14 predictor = sklearn_estimator.deploy(                                                       │
# │   15 │   initial_instance_count=1,                                                               │
# │   16 │   instance_type="ml.m5.large"                                                             │
# │   17 )                                                                                           │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/estima │
# │ tor.py:1722 in deploy                                                                            │
# │                                                                                                  │
# │   1719 │   │   │   inference_tags=format_tags(tags), training_tags=self.tags                     │
# │   1720 │   │   )                                                                                 │
# │   1721 │   │                                                                                     │
# │ ❱ 1722 │   │   return model.deploy(                                                              │
# │   1723 │   │   │   instance_type=instance_type,                                                  │
# │   1724 │   │   │   initial_instance_count=initial_instance_count,                                │
# │   1725 │   │   │   serializer=serializer,                                                        │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/model. │
# │ py:1737 in deploy                                                                                │
# │                                                                                                  │
# │   1734 │   │   │   return None                                                                   │
# │   1735 │   │                                                                                     │
# │   1736 │   │   else:  # existing single model endpoint path                                      │
# │ ❱ 1737 │   │   │   self._create_sagemaker_model(                                                 │
# │   1738 │   │   │   │   instance_type=instance_type,                                              │
# │   1739 │   │   │   │   accelerator_type=accelerator_type,                                        │
# │   1740 │   │   │   │   tags=tags,                                                                │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/model. │
# │ py:986 in _create_sagemaker_model                                                                │
# │                                                                                                  │
# │    983 │   │   │   │   enable_network_isolation=self._enable_network_isolation,                  │
# │    984 │   │   │   │   tags=format_tags(tags),                                                   │
# │    985 │   │   │   )                                                                             │
# │ ❱  986 │   │   │   self.sagemaker_session.create_model(**create_model_args)                      │
# │    987 │                                                                                         │
# │    988 │   def _get_model_uri(self):                                                             │
# │    989 │   │   model_uri = None                                                                  │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/sessio │
# │ n.py:4109 in create_model                                                                        │
# │                                                                                                  │
# │   4106 │   │   │   │   else:                                                                     │
# │   4107 │   │   │   │   │   raise                                                                 │
# │   4108 │   │                                                                                     │
# │ ❱ 4109 │   │   self._intercept_create_request(create_model_request, submit, self.create_model._  │
# │   4110 │   │   return name                                                                       │
# │   4111 │                                                                                         │
# │   4112 │   def create_model_from_job(                                                            │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/sessio │
# │ n.py:6808 in _intercept_create_request                                                           │
# │                                                                                                  │
# │   6805 │   │   │   create (functor): a functor calls the sagemaker client create method          │
# │   6806 │   │   │   func_name (str): the name of the function needed intercepting                 │
# │   6807 │   │   """                                                                               │
# │ ❱ 6808 │   │   return create(request)                                                            │
# │   6809 │                                                                                         │
# │   6810 │   def _create_inference_recommendations_job_request(                                    │
# │   6811 │   │   self,                                                                             │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/sessio │
# │ n.py:4097 in submit                                                                              │
# │                                                                                                  │
# │   4094 │   │   │   logger.info("Creating model with name: %s", name)                             │
# │   4095 │   │   │   logger.debug("CreateModel request: %s", json.dumps(request, indent=4))        │
# │   4096 │   │   │   try:                                                                          │
# │ ❱ 4097 │   │   │   │   self.sagemaker_client.create_model(**request)                             │
# │   4098 │   │   │   except ClientError as e:                                                      │
# │   4099 │   │   │   │   error_code = e.response["Error"]["Code"]                                  │
# │   4100 │   │   │   │   message = e.response["Error"]["Message"]                                  │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/client. │
# │ py:570 in _api_call                                                                              │
# │                                                                                                  │
# │    567 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    568 │   │   │   │   )                                                                         │
# │    569 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  570 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    571 │   │                                                                                     │
# │    572 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    573                                                                                           │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/context │
# │ .py:124 in wrapper                                                                               │
# │                                                                                                  │
# │   121 │   │   │   with start_as_current_context():                                               │
# │   122 │   │   │   │   if hook:                                                                   │
# │   123 │   │   │   │   │   hook()                                                                 │
# │ ❱ 124 │   │   │   │   return func(*args, **kwargs)                                               │
# │   125 │   │                                                                                      │
# │   126 │   │   return wrapper                                                                     │
# │   127                                                                                            │
# │                                                                                                  │
# │ /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/client. │
# │ py:1031 in _make_api_call                                                                        │
# │                                                                                                  │
# │   1028 │   │   │   │   "Code"                                                                    │
# │   1029 │   │   │   )                                                                             │
# │   1030 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1031 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1032 │   │   else:                                                                             │
# │   1033 │   │   │   return parsed_response                                                        │
# │   1034                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ClientError: An error occurred (ValidationException) when calling the CreateModel operation: Could not find model
# data at s3://dana-minicapstone/model-artifacts/sagemaker-scikit-learn-2025-04-09-07-26-12-644/output/model.tar.gz.

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# # Create a boto3 session in us-east-2
# boto_session = boto3.Session(region_name="us-east-2")
# sagemaker_session = sagemaker.Session(boto_session=boto_session)

# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
# data_path = "s3://dana-minicapstone/data/occupancy_model_zones.csv"
# job_name = "occupancy-model-t1"

# sklearn_estimator = SKLearn(
#     entry_point="occupancy_model.py",
#     source_dir=".",                        # Package everything in the current directory
#     dependencies=["requirements.txt"],     # Ensure this file is local
#     role=role,
#     instance_type="ml.m5.xlarge",
#     framework_version="0.23-1",
#     output_path="s3://dana-minicapstone/model-artifacts/",
#     sagemaker_session=sagemaker_session,
#     job_name=job_name
# )

# sklearn_estimator.fit()

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# # Create a boto3 session in the region of your S3 bucket
# region = "us-east-2"
# boto_session = boto3.Session(region_name=region)
# sagemaker_session = sagemaker.Session(boto_session=boto_session)

# # Set your SageMaker execution role ARN (ensure it has required S3 permissions)
# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"

# # S3 paths for data and model artifacts
# data_path = "s3://dana-minicapstone/data/occupancy_model_zones.csv"
# output_path = "s3://dana-minicapstone/model-artifacts/"

# # Define a unique job name for training (you can customize it)
# job_name = "occupancy-model-t1"

# %%
# # Create the SKLearn estimator using your training script
# sklearn_estimator = SKLearn(
#     entry_point="occupancy_model.py",         # Your training script file
#     source_dir=".",                           # Package local directory contents
#     dependencies=["requirements.txt"],        # List additional dependencies if needed
#     role=role,
#     instance_type="ml.m5.xlarge",             # Instance type (adjust if needed)
#     framework_version="0.23-1",               # scikit-learn container version
#     output_path=output_path,
#     sagemaker_session=sagemaker_session,
#     job_name=job_name
# )

# # Launch the training job
# sklearn_estimator.fit()

# %%
# # Deploy the trained model to an endpoint
# predictor = sklearn_estimator.deploy(
#     initial_instance_count=1,
#     instance_type="ml.m5.xlarge",
#     endpoint_name="occupancy-model-endpoint"
# )

# print("Endpoint deployed. Name:", predictor.endpoint_name)

# %%
# import json
# import pandas as pd

# # Create sample input data. This should be a list of dictionaries,
# # where keys match feature names used in your training script.
# sample_input = [
#     {"Environment:Site Outdoor Air Relative Humidity[%]": 83.66667,
#      "Environment:Site Outdoor Air Dewpoint Temperature[C]": 16.95,
#      "Environment:Site Outdoor Air Wetbulb Temperature[C]": 19.82,
#      "Environment:Site Outdoor Air Drybulb Temperature[C]": 19.82,
#      # include other numerical features as expected by your training script;
#      # note: make sure to add the same features used during training (minus the derived ones)
#     }
# ]

# # Make a prediction (the input_fn, predict_fn, output_fn in inference.py handle processing)
# result = predictor.predict(sample_input)
# print("Predictions:", result)

# %%
# predictor.delete_endpoint()
# print("Endpoint deleted.")

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# region = "us-east-2"
# boto_session = boto3.Session(region_name=region)
# sagemaker_session = sagemaker.Session(boto_session=boto_session)
# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
# data_path = "s3://dana-minicapstone/data/hvac_model_zones.csv"
# output_path = "s3://dana-minicapstone/model-artifacts/"

# sklearn_estimator = SKLearn(
#     entry_point="hvac_model.py",   # filename of your script
#     source_dir=".",                # directory containing your code and dependencies
#     dependencies=["requirements.txt"],  # if needed; ensure the file exists locally
#     role=role,
#     instance_type="ml.m5.xlarge",
#     framework_version="0.23-1",
#     output_path=output_path,
#     sagemaker_session=sagemaker_session,
#     job_name="hvac-model-training-job"  # a unique training job name
# )

# sklearn_estimator.fit()

# %%
import boto3
import sagemaker
from sagemaker.sklearn.estimator import SKLearn

# Create a boto3 session in us-east-2
boto_session = boto3.Session(region_name="us-east-2")
sagemaker_session = sagemaker.Session(boto_session=boto_session)

role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
job_name = "occupancy-model-t1"

sklearn_estimator = SKLearn(
    entry_point="hvac_test.py",      # Your training script
    source_dir=".",                        # Packages all the files from the current directory
    dependencies=["requirements.txt"],     # Installs any extra packages listed here
    role=role,
    instance_type="ml.m5.xlarge",
    framework_version="0.23-1",
    output_path="s3://dana-minicapstone/model-artifacts/",  # Where the model artifacts will be stored
    sagemaker_session=sagemaker_session,
    job_name=job_name
)

sklearn_estimator.fit()  # Submits the training job to SageMaker
# Out:
# [04/09/25 00:42:44] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=82944;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=547614;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/botocore/credentials.py#1352\1352]8;;\
# [04/09/25 00:42:45] INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=131642;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=460607;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/telemetry/telemetry_logging.py#91\91]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
# ...

# %%
predictor = sklearn_estimator.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.large"
)
# Out:
# [04/09/25 10:29:45] INFO     Creating model with name:                                              ]8;id=359565;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=845588;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#4094\4094]8;;\
#                              sagemaker-scikit-learn-2025-04-09-17-29-45-121
# [04/09/25 10:29:46] INFO     Creating endpoint-config with name                                     ]8;id=967699;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=814341;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#6019\6019]8;;\
#                              sagemaker-scikit-learn-2025-04-09-17-29-45-121
# ...

# %%
from sagemaker.sklearn.model import SKLearnModel

role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
model_data = "s3://dana-minicapstone/model-artifacts/sagemaker-scikit-learn-2025-04-09-07-42-45-423/output/model.tar.gz"  # update with your S3 path

model = SKLearnModel(
    model_data=model_data,
    role=role,
    entry_point="inference_hvac_test.py",  # Reference your inference script
    framework_version="0.23-1",
    py_version="py3"
)

# Deploy the model to create an endpoint
predictor = model.deploy(initial_instance_count=1, instance_type="ml.m5.large")
# Out:
# [04/09/25 11:11:07] INFO     Creating model with name:                                              ]8;id=714756;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=617126;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#4094\4094]8;;\
#                              sagemaker-scikit-learn-2025-04-09-18-11-07-676
# [04/09/25 11:11:08] INFO     Creating endpoint-config with name                                     ]8;id=86027;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=895330;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sagemaker/session.py#6019\6019]8;;\
#                              sagemaker-scikit-learn-2025-04-09-18-11-08-673
# ...

# %%
import boto3
import io

# Read test CSV from S3
s3 = boto3.client('s3', region_name='us-east-2')
bucket = "dana-minicapstone"
key = "data/hvac_test.csv"
response = s3.get_object(Bucket=bucket, Key=key)
test_csv = response['Body'].read().decode('utf-8')

# Invoke the endpoint
result = predictor.predict(test_csv)
print("Predictions:\n", result)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:12                                                                                   │
# │                                                                                                  │
# │    9 test_csv = response['Body'].read().decode('utf-8')                                          │
# │   10                                                                                             │
# │   11 # Invoke the endpoint                                                                       │
# │ ❱ 12 result = predictor.predict(test_csv)                                                        │
# │   13 print("Predictions:\n", result)                                                             │
# │   14                                                                                             │
# ...

# %%
# import boto3
# import io

# # 1. Retrieve the test CSV from S3
# s3 = boto3.client('s3', region_name='us-east-2')
# bucket_name = "dana-minicapstone"
# key = "data/hvac_test.csv"

# response = s3.get_object(Bucket=bucket_name, Key=key)
# csv_bytes = response['Body'].read()       # Get the raw bytes
# csv_str = csv_bytes.decode('utf-8')       # Convert bytes to string


# predictor = sklearn_estimator.deploy(
#     initial_instance_count=1,
#     instance_type="ml.m5.large"
# )

# # 2. Invoke the deployed endpoint with the CSV string
# result = predictor.predict(csv_str)

# # 3. Examine the result (e.g. printing)
# print(result)

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# # Create a boto3 session in us-east-2
# boto_session = boto3.Session(region_name="us-east-2")
# sagemaker_session = sagemaker.Session(boto_session=boto_session)

# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
# data_path = "s3://dana-minicapstone/data/occupancy_model_zones.csv"
# job_name = "occupancy-model-t1"

# sklearn_estimator = SKLearn(
#     entry_point="occupancy_model.py",
#     source_dir=".",                        # Package everything in the current directory
#     dependencies=["requirements.txt"],     # Ensure this file is local
#     role=role,
#     instance_type="ml.m5.xlarge",
#     framework_version="0.23-1",
#     output_path="s3://dana-minicapstone/model-artifacts/",
#     sagemaker_session=sagemaker_session,
#     job_name=job_name
# )

# sklearn_estimator.fit()

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# # Create a boto3 session in the region of your S3 bucket
# region = "us-east-2"
# boto_session = boto3.Session(region_name=region)
# sagemaker_session = sagemaker.Session(boto_session=boto_session)

# # Set your SageMaker execution role ARN (ensure it has required S3 permissions)
# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"

# # S3 paths for data and model artifacts
# data_path = "s3://dana-minicapstone/data/occupancy_model_zones.csv"
# output_path = "s3://dana-minicapstone/model-artifacts/"

# # Define a unique job name for training (you can customize it)
# job_name = "occupancy-model-t1"

# %%
# # Create the SKLearn estimator using your training script
# sklearn_estimator = SKLearn(
#     entry_point="occupancy_model.py",         # Your training script file
#     source_dir=".",                           # Package local directory contents
#     dependencies=["requirements.txt"],        # List additional dependencies if needed
#     role=role,
#     instance_type="ml.m5.xlarge",             # Instance type (adjust if needed)
#     framework_version="0.23-1",               # scikit-learn container version
#     output_path=output_path,
#     sagemaker_session=sagemaker_session,
#     job_name=job_name
# )

# # Launch the training job
# sklearn_estimator.fit()

# %%
# # Deploy the trained model to an endpoint
# predictor = sklearn_estimator.deploy(
#     initial_instance_count=1,
#     instance_type="ml.m5.xlarge",
#     endpoint_name="occupancy-model-endpoint"
# )

# print("Endpoint deployed. Name:", predictor.endpoint_name)

# %%
# import json
# import pandas as pd

# # Create sample input data. This should be a list of dictionaries,
# # where keys match feature names used in your training script.
# sample_input = [
#     {"Environment:Site Outdoor Air Relative Humidity[%]": 83.66667,
#      "Environment:Site Outdoor Air Dewpoint Temperature[C]": 16.95,
#      "Environment:Site Outdoor Air Wetbulb Temperature[C]": 19.82,
#      "Environment:Site Outdoor Air Drybulb Temperature[C]": 19.82,
#      # include other numerical features as expected by your training script;
#      # note: make sure to add the same features used during training (minus the derived ones)
#     }
# ]

# # Make a prediction (the input_fn, predict_fn, output_fn in inference.py handle processing)
# result = predictor.predict(sample_input)
# print("Predictions:", result)

# %%
# predictor.delete_endpoint()
# print("Endpoint deleted.")

# %%
# import boto3
# import sagemaker
# from sagemaker.sklearn.estimator import SKLearn

# region = "us-east-2"
# boto_session = boto3.Session(region_name=region)
# sagemaker_session = sagemaker.Session(boto_session=boto_session)
# role = "arn:aws:iam::222634404112:role/SageMakerExecutionRole"
# data_path = "s3://dana-minicapstone/data/hvac_model_zones.csv"
# output_path = "s3://dana-minicapstone/model-artifacts/"

# sklearn_estimator = SKLearn(
#     entry_point="hvac_model.py",   # filename of your script
#     source_dir=".",                # directory containing your code and dependencies
#     dependencies=["requirements.txt"],  # if needed; ensure the file exists locally
#     role=role,
#     instance_type="ml.m5.xlarge",
#     framework_version="0.23-1",
#     output_path=output_path,
#     sagemaker_session=sagemaker_session,
#     job_name="hvac-model-training-job"  # a unique training job name
# )

# sklearn_estimator.fit()
